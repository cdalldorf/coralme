# %%
# use the coralme_old2 environment for this
import coralme
import pandas
from coralme.solver.solver import ME_NLP
import cobra
import numpy
from coralme.core.optimization import _check_options
from coralme.core.optimization import construct_lp_problem

#from coralme.core.optimization import fva
import matplotlib.pyplot as plt
plt.rcParams['svg.fonttype'] = 'none'
pandas.set_option('display.max_colwidth', None)
import inspect

import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.metrics import r2_score
import math
import os
import pickle
import pandas as pd

coralme_dir = '/home/chris/zuniga/coralme/' #'../'

# build pathway reference using Carlos mapping
models_carlos_df = pd.read_csv(os.path.join(coralme_dir, 'data', 'external', 'geneIDsMapping_PA14_vs_Strains_SubsystemInfo.csv'), index_col = 0)

# %%
# check for solutions, run
base_dir = os.path.join(coralme_dir, 'species_files', 'Pseudomonas_files')
for f in os.listdir(os.path.join(base_dir, 'individual_species')):
    if 'Reference' in f: continue

    # load and run model
    print(f+' working...', end = '')
    out_path = os.path.join(base_dir, 'individual_species', f, 'outputs')
    M_model_path = os.path.join(out_path, 'pathway_annotated_M_model.sbml')
    M_model = cobra.io.sbml.read_sbml_model(M_model_path)
    M_sol_path = os.path.join(base_dir, 'individual_species', f, 'outputs', 'M_flux_solution.pkl')
    M_flux_path = os.path.join(base_dir, 'individual_species', f, 'outputs', 'M_flux_ref_solution_dict.pkl')
    M_flux_path2 = os.path.join(base_dir, 'individual_species', f, 'outputs', 'M_flux_carlos_solution_dict.pkl')
    
    model_ = coralme.core.model.MEModel.from_cobra(M_model)
    model_.optimize()
    solution = model_.solution
    
    # if there is a solution, create pathway to flux and annotation, save them
    if solution:
        print('solution found!')
        rxns = []
        fluxes = []
        pathways = []
        rxns2 = []
        fluxes2 = []
        pathways2 = []
        for rxn, flux in model_.solution.fluxes.items():
            M_rxn = M_model.reactions.get_by_id(rxn)
            if 'ref_pathways' in M_rxn.annotation:
                rxns.append(rxn)
                fluxes.append(flux)
                pathways.append(M_rxn.annotation['ref_pathways'])
            paths_temp = set()
            for gene in M_rxn.gpr.genes:
                check = models_carlos_df[models_carlos_df[f] == gene]
                if len(check) > 0:
                    sub = models_carlos_df[models_carlos_df[f] == gene].Subsystem.values[0]
                    paths_temp.add(sub)
            if len(paths_temp) > 0:
                paths_temp = list(paths_temp)
                paths_temp.sort()
                rxns2.append(rxn)
                fluxes2.append(flux)
                pathways2.append(paths_temp)
        flux_df = pd.DataFrame(index = rxns)
        flux_df['flux'] = fluxes
        flux_df['pathways'] = pathways
        flux_df.to_pickle(M_flux_path)
        flux_df2 = pd.DataFrame(index = rxns2)
        flux_df2['flux'] = fluxes2
        flux_df2['pathways'] = pathways2
        flux_df2.to_pickle(M_flux_path2)
        
        # save off solution
        pickle_out = open(M_sol_path, 'wb')
        pickle.dump(solution, pickle_out)
        pickle_out.close()
    else:
        print('no solution :(')
        # save something bogus to prevent rerunning this
        pickle_out = open(M_flux_path, 'wb')
        pickle.dump(False, pickle_out)
        pickle_out.close()
        
        # save off solution
        pickle_out = open(M_sol_path, 'wb')
        pickle.dump(False, pickle_out)
        pickle_out.close()
# Out:
# CP008896 working...Restricted license - for non-production use only - expires 2025-11-24
# Read LP format model from file /tmp/tmpzma1b0y6.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3528 columns, 14272 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP053697 working...Read LP format model from file /tmp/tmp9vdbkzpt.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3182 columns, 12760 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP026386 working...Read LP format model from file /tmp/tmpwq2c4ujw.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3486 columns, 14140 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP069317 working...Read LP format model from file /tmp/tmp0kxhomsm.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3376 columns, 13572 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# AE004091.2 working...
# '' is not a valid SBML 'SId'.
# Read LP format model from file /tmp/tmpeke7qvcg.lp
# Reading time = 0.01 seconds
# : 1648 rows, 4034 columns, 16642 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP014784 working...Read LP format model from file /tmp/tmp9f6zq9z1.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3268 columns, 13122 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP073105 working...Read LP format model from file /tmp/tmpg36vjepd.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3258 columns, 12992 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP065866 working...Read LP format model from file /tmp/tmpwpslixpp.lp
# Reading time = 0.01 seconds
# : 1648 rows, 4048 columns, 16704 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP061848 working...Read LP format model from file /tmp/tmpdx1esskt.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3478 columns, 14098 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP012831 working...Read LP format model from file /tmp/tmp7vddn111.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3512 columns, 14314 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# '' is not a valid SBML 'SId'.
# CP008749.1 working...Read LP format model from file /tmp/tmpl8h_6a2e.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3994 columns, 16410 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP032419 working...Read LP format model from file /tmp/tmp3gk3pvfo.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3380 columns, 13646 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP038001 working...Read LP format model from file /tmp/tmp29y3y6ls.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3576 columns, 14520 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP022560 working...Read LP format model from file /tmp/tmpsmga_0ui.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3486 columns, 14138 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP076683 working...Read LP format model from file /tmp/tmpw_hwy4n6.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3256 columns, 13090 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP045416 working...Read LP format model from file /tmp/tmpryx_i522.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3198 columns, 12710 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# AP022324 working...Read LP format model from file /tmp/tmphve746yn.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3500 columns, 14164 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# LS483372 working...Read LP format model from file /tmp/tmp90i3aahw.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3528 columns, 14256 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP022562 working...Read LP format model from file /tmp/tmp_su5n2w0.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3464 columns, 14024 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# LR590473 working...Read LP format model from file /tmp/tmp04bvvm0j.lp
# Reading time = 0.01 seconds
# : 1648 rows, 4022 columns, 16586 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP065865 working...Read LP format model from file /tmp/tmpi1q2qg1t.lp
# Reading time = 0.01 seconds
# : 1648 rows, 4038 columns, 16642 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP058975 working...Read LP format model from file /tmp/tmpfv5ixcur.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3536 columns, 14332 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP012830 working...Read LP format model from file /tmp/tmpa21aqb94.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3544 columns, 14460 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# '' is not a valid SBML 'SId'.
# AP014655.1 working...Read LP format model from file /tmp/tmpw7d92ncf.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3194 columns, 12692 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP061335 working...Read LP format model from file /tmp/tmp1emcp0f_.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3470 columns, 14056 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP068238 working...Read LP format model from file /tmp/tmppkam5h6e.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3994 columns, 16362 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP050291 working...Read LP format model from file /tmp/tmpmqxn304b.lp
# Reading time = 0.03 seconds
# : 1648 rows, 3448 columns, 13960 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP070982 working...Read LP format model from file /tmp/tmp3q5ut7yv.lp
# Reading time = 0.02 seconds
# : 1648 rows, 3476 columns, 14078 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP000712 working...Read LP format model from file /tmp/tmpxsa7etqm.lp
# Reading time = 0.02 seconds
# : 1648 rows, 3476 columns, 14066 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# AP024503 working...Read LP format model from file /tmp/tmpk035uvnj.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3602 columns, 14618 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP045349 working...Read LP format model from file /tmp/tmpxalqeai9.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3376 columns, 13750 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP063780 working...Read LP format model from file /tmp/tmpr_6h71ac.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3548 columns, 14340 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP024478 working...Read LP format model from file /tmp/tmpvfvyi7ec.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3438 columns, 13962 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP022561 working...Read LP format model from file /tmp/tmpqbd0_ov7.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3490 columns, 14124 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP065867 working...Read LP format model from file /tmp/tmpk9fl4sk_.lp
# Reading time = 0.01 seconds
# : 1648 rows, 4038 columns, 16654 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP020100 working...Read LP format model from file /tmp/tmpigpmizxx.lp
# Reading time = 0.01 seconds
# : 1648 rows, 2910 columns, 11308 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP039749 working...Read LP format model from file /tmp/tmpk2us5l_v.lp
# Reading time = 0.01 seconds
# : 1648 rows, 4048 columns, 16708 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP041013 working...Read LP format model from file /tmp/tmp5umikr3x.lp
# Reading time = 0.01 seconds
# : 1648 rows, 4048 columns, 16708 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP015225 working...Read LP format model from file /tmp/tmpmpall_eu.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3492 columns, 14256 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP045359 working...Read LP format model from file /tmp/tmpye04bkz8.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3376 columns, 13750 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP043320 working...Read LP format model from file /tmp/tmpmrtcsh3c.lp
# Reading time = 0.01 seconds
# : 1648 rows, 2758 columns, 10628 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP060288 working...Read LP format model from file /tmp/tmp3kehc_sl.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3366 columns, 13576 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!
# CP043179 working...Read LP format model from file /tmp/tmpz_xpusis.lp
# Reading time = 0.01 seconds
# : 1648 rows, 3656 columns, 14914 nonzeros
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# solution found!

# %% [markdown]
# # old way (didn't work well)

# %%
# imports
import os
import sys

# code for enabling this notebook to work within cursor
coralme_dir = '/home/chris/zuniga/coralme/' #'../'
sys.path.insert(0, coralme_dir)

import importlib
import coralme
import cobra

# %%
# check for solutions, run if nonexistant
base_dir = os.path.join(coralme_dir, 'species_files', 'Pseudomonas_files')
for f in os.listdir(os.path.join(base_dir, 'individual_species')):
    if 'Reference' in f: continue

    # file pathing
    M_model_path = os.path.join(base_dir, 'individual_species', f, 'inputs', 'model.xml')
    ME_model_path = os.path.join(base_dir, 'individual_species', f, 'outputs', 'pathway_annotated_model.pkl')
    M_v2_model_path = os.path.join(base_dir, 'individual_species', f, 'inputs', 'M_as_ME_for_QMINOS_model.json')
    
    # translate model to ME format
    #M_model = cobra.io.load_json_model(M_model_path)
    M_model = cobra.io.read_sbml_model(M_model_path)
    pseudo_ME_model = coralme.core.model.MEModel(M_model)
    pseudo_ME_model.add_metabolites(M_model.metabolites)
    #coralme.io.json.save_json_model(pseudo_ME_model, M_v2_model_path)
    
    # run model
    sol = pseudo_ME_model.optimize(max_mu = 0.000002, min_mu = 0.00000000001, lambdify = False)
    continue
    
    # run M model simulations
    M_model_path = os.path.join(base_dir, 'individual_species', f, 'inputs', 'model.json')
    M_v2_model_path = os.path.join(base_dir, 'individual_species', f, 'inputs', 'M_as_ME_for_QMINOS_model.json')
    if True: # zzz force_rerun or not os.path.exists(M_sol_path):
        print('creating M model...', end = '')
        if True:#not os.path.exists(M_v2_model_path): # zzz xxx todo
            # let's make the model
            temp_M_model = cobra.io.load_json_model(M_model_path)
            for rxn in temp_M_model.reactions:
                rxn.cofactors = []
            M_as_ME_model = coralme.core.model.MEModel.from_cobra(temp_M_model)
            M_as_ME_model.global_info.update({
                'kt': 4.5,  # This was k_t in your default_parameters
                'r0': 0.087,
                'k_deg': 12.0,  # This was k^mRNA_deg in your default_parameters
                'm_rr': 1453.0,
                'm_aa': 0.109,
                'f_rRNA': 0.86,
                'm_nt': 0.324,
                'f_mRNA': 0.02,
                'm_tRNA': 25.0,
                'f_tRNA': 0.12
            })
            coralme.io.json.save_json_me_model(M_as_ME_model, M_v2_model_path)
        else:
            M_model = coralme.io.json.load_json_me_model(M_v2_model_path)

        # run on this default medium
        continue # zzz maybe remove this? for now just create models
        print('done(ish)!') # zzz and remove this
        
        solution = M_model.optimize(max_mu = 0.5, min_mu = 0.01, tolerance = 1e-4, maxIter = 20)
    
        # if there is a solution, create pathway to flux and annotation, save them
        if solution:
            print('saving solution...', end = '')
            rxns = []
            fluxes = []
            pathways = []
            for rxn, flux in M_model.solution.fluxes.items():
                M_rxn = M_model.reactions.get_by_id(rxn)
                if 'ref_pathways' in M_rxn.annotation:
                    rxns.append(rxn)
                    fluxes.append(flux)
                    pathways.append(M_rxn.annotation['ref_pathways'])
            flux_df = pd.DataFrame(index = rxns)
            flux_df['flux'] = fluxes
            flux_df['pathways'] = pathways
            flux_df.to_pickle(M_flux_path)
        
            # save off solution
            pickle_out = open(M_sol_path, 'wb')
            pickle.dump(ME_model.solution, pickle_out)
            pickle_out.close()
        else:
            print('no solution...', end = '')
            # save something bogus to prevent rerunning this
            pickle_out = open(M_flux_path, 'wb')
            pickle.dump(False, pickle_out)
            pickle_out.close()
            
            # save off solution
            pickle_out = open(M_sol_path, 'wb')
            pickle.dump(False, pickle_out)
            pickle_out.close()
    print('done!')
# Out:
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# '' is not a valid SBML 'SId'.
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# '' is not a valid SBML 'SId'.
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# '' is not a valid SBML 'SId'.
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0000010000050000	Not feasible

# %%
pseudo_ME_model.optimize(max_mu = 0.02, min_mu = 0.001, lambdify = False)
# Out:
# The MINOS and quad MINOS solvers are a courtesy of Prof Michael A. Saunders. Please cite Ma, D., Yang, L., Fleming, R. et al. Reliable and efficient solution of genome-scale models of Metabolism and macromolecular Expression. Sci Rep 7, 40863 (2017). https://doi.org/10.1038/srep40863
#
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0100000000050000	Not feasible
#         2	0.0050000000075000	Not feasible
#         3	0.0025000000087500	Not feasible
#         4	0.0012500000093750	Not feasible
#         5	0.0006250000096875	Not feasible
#         6	0.0003125000098438	Not feasible
#         7	0.0001562500099219	Not feasible
#         8	0.0000781250099609	Not feasible
#         9	0.0000390625099805	Not feasible
#        10	0.0000195312599902	Not feasible
#        11	0.0000097656349951	Not feasible
#        12	0.0000048828224976	Not feasible
#        13	0.0000024414162488	Not feasible
#        14	0.0000012207131244	Not feasible
#        15	0.0000006103615622	Not feasible
# False
